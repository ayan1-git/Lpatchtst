# %% [markdown]
# # LPatchTST Training on Kaggle
# This notebook clones the repository, installs dependencies (including TA-Lib), and runs the training pipeline.

# %%
import os
# Reset to the base working directory
# %cd /kaggle/working

if not os.path.exists("Lpatchtst"):
    # !git clone https://github.com/ayan1-git/Lpatchtst
else:
    print("Repo already exists, pulling updates...")
    # %cd Lpatchtst
    # !git pull
    # %cd ..

# %cd Lpatchtst
# Out:
# /kaggle/working
# Repo already exists, pulling updates...
# /kaggle/working/Lpatchtst
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 327 bytes | 327.00 KiB/s, done.
# From https://github.com/ayan1-git/Lpatchtst
#    a0d7923..c0abb6e  main       -> origin/main
# Updating a0d7923..c0abb6e
# Fast-forward
#  config.py | 12 ++++++------
#  1 file changed, 6 insertions(+), 6 deletions(-)
# /kaggle/working
# /kaggle/working/Lpatchtst

# %%
# !torchrun --nproc_per_node=2 train_pretrain_fine.py
# Out:
# W0525 15:34:12.711000 1115 torch/distributed/run.py:852]
# W0525 15:34:12.711000 1115 torch/distributed/run.py:852] *****************************************
# W0525 15:34:12.711000 1115 torch/distributed/run.py:852] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0525 15:34:12.711000 1115 torch/distributed/run.py:852] *****************************************
# [dist] Backend=nccl  Device=cuda:0  Rank=0/2
# Processing Data/NIFTY 100_30minute.csv…
# [dist] Backend=nccl  Device=cuda:1  Rank=1/2
# 2026-05-25 15:34:16,936 | INFO     | features | Building features for 'close' | 36033 rows | ohlc=True.
# ...

# %%
# Now run evaluate
# !python evaluate.py
# Out:
# Loading data from Data/NIFTY 50_30minute.csv…
# FeatureEngineer | ewma_span=260 | horizons=[1, 3, 6, 13, 26, 65, 130, 260] | macd_pairs=[(8, 24), (26, 78), (52, 156)]
# 2026-05-20 08:50:49,150 | INFO     | features | Building features for 'close' | 36047 rows | ohlc=True.
# 2026-05-20 08:50:49,889 | WARNING  | features | session_cyclic_features: DatetimeIndex is tz-naive. Assuming timestamps are already in Asia/Kolkata. If your data is UTC or another timezone, localize before calling: index = index.tz_localize('UTC').tz_convert('Asia/Kolkata')
# 2026-05-20 08:50:49,928 | INFO     | features | Feature matrix built: shape=(36047, 20) | NaN count=11670
# ...

# %%
# !pip install -q huggingface_hub
